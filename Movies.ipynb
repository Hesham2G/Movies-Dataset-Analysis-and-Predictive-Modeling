# %%
import pandas as pd

# %%
df = pd.read_csv('movies.csv')
df
# Out:
#       Unnamed: 0     id     budget  popularity     revenue  \
# 0              0  43597  237000000         150  2787965087
# 1              1  43598  300000000         139   961000000
# 2              2  43599  245000000         107   880674609
# 3              3  43600  250000000         112  1084939099
# 4              5  43602  258000000         115   890871626
# ...          ...    ...        ...         ...         ...
# 1460        4736  48363          0           3      321952
# 1461        4743  48370      27000          19     3151130
# 1462        4748  48375          0           7           0
# 1463        4749  48376          0           3           0
# 1464        4768  48395     220000          14     2040920
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# ...

# %%
df.shape
# Out:
# (1465, 12)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'id', 'budget', 'popularity', 'revenue', 'title',
#        'vote_average', 'vote_count', 'director_id', 'year', 'month', 'day'],
#       dtype='object')

# %%
df.head(10)
# Out:
#    Unnamed: 0     id     budget  popularity     revenue  \
# 0           0  43597  237000000         150  2787965087
# 1           1  43598  300000000         139   961000000
# 2           2  43599  245000000         107   880674609
# 3           3  43600  250000000         112  1084939099
# 4           5  43602  258000000         115   890871626
# 5           9  43606  250000000         155   873260194
# 6          10  43607  270000000          57   391081192
# 7          11  43608  200000000         107   586090727
# 8          12  43609  200000000         145  1065659812
# 9          13  43610  255000000          49    89289910
#
#                                         title  vote_average  vote_count  \
# 0                                      Avatar           7.2       11800
# 1    Pirates of the Caribbean: At World's End           6.9        4500
# 2                                     Spectre           6.3        4466
# ...

# %%
df.describe()
# Out:
#         Unnamed: 0            id        budget   popularity       revenue  \
# count  1465.000000   1465.000000  1.465000e+03  1465.000000  1.465000e+03
# mean   1627.391809  45225.191126  4.802295e+07    30.855973  1.432539e+08
# std    1187.182894   1189.096396  4.935541e+07    34.845214  2.064918e+08
# min       0.000000  43597.000000  0.000000e+00     0.000000  0.000000e+00
# 25%     639.000000  44236.000000  1.400000e+07    11.000000  1.738013e+07
# 50%    1425.000000  45022.000000  3.300000e+07    23.000000  7.578164e+07
# 75%    2393.000000  45990.000000  6.600000e+07    41.000000  1.792469e+08
# max    4768.000000  48395.000000  3.800000e+08   724.000000  2.787965e+09
#
#        vote_average    vote_count  director_id         year
# count   1465.000000   1465.000000  1465.000000  1465.000000
# mean       6.368191   1146.396587  5040.192491  2002.615017
# std        0.818033   1578.077438   258.059631     8.680141
# min        3.000000      1.000000  4762.000000  1976.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    1465 non-null   int64
#  1   id            1465 non-null   int64
#  2   budget        1465 non-null   int64
#  3   popularity    1465 non-null   int64
#  4   revenue       1465 non-null   int64
#  5   title         1465 non-null   object
#  6   vote_average  1465 non-null   float64
#  7   vote_count    1465 non-null   int64
#  8   director_id   1465 non-null   int64
#  9   year          1465 non-null   int64
#  10  month         1465 non-null   object
#  11  day           1465 non-null   object
# dtypes: float64(1), int64(8), object(3)
# memory usage: 137.5+ KB

# %%
df.isna().sum()
# Out:
# Unnamed: 0      0
# id              0
# budget          0
# popularity      0
# revenue         0
# title           0
# vote_average    0
# vote_count      0
# director_id     0
# year            0
# month           0
# day             0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.nunique()
# Out:
# Unnamed: 0      1465
# id              1465
# budget           201
# popularity       128
# revenue         1267
# title           1465
# vote_average      51
# vote_count      1019
# director_id      199
# year              41
# month             12
# day                7
# dtype: int64

# %%
release_day_counts = df['day'].value_counts()
release_day_counts
# Out:
# day
# Friday       654
# Thursday     277
# Wednesday    276
# Tuesday       98
# Monday        67
# Saturday      47
# Sunday        46
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.bar(release_day_counts.index, release_day_counts.values, color='orange', edgecolor='black')

plt.xticks(release_day_counts.index, release_day_counts.index, rotation=45)

plt.xlabel("Day of the Week", fontsize=14)
plt.ylabel("Total Movies Released", fontsize=14)
plt.title("Overall Distribution of Total Movies Released by Day of the Week", fontsize=16)

plt.show()

# %%
Friday_counts = 654
Thursday_counts = 277
Wednesday_counts = 276
Tuesday_counts = 98
Monday_counts = 67
Saturday_counts = 47
Sunday_counts = 46

index_values = [Friday_counts, Thursday_counts, Wednesday_counts, Tuesday_counts, Monday_counts, Saturday_counts, Sunday_counts]
index_labels = ['Friday', 'Thursday', 'Wednesday', 'Tuesday' , 'Monday', 'Saturday', 'Sunday']

plt.figure(figsize=(10,6))
plt.pie(index_values, labels = index_labels, autopct='%2.3f%%')

plt.title('Overall Distribution of Total Movies Released by Day of the Week', fontsize=16)

plt.show()

# %%
release_month_counts = df['month'].value_counts()
release_month_counts
# Out:
# month
# Dec    193
# Sep    166
# Oct    149
# Jun    133
# Jul    127
# Nov    117
# May    116
# Aug    111
# Feb    104
# Mar     99
# Apr     90
# Jan     60
# Name: count, dtype: int64

# %%
release_year_counts = df['year'].value_counts()
release_year_counts
# Out:
# year
# 2006    73
# 2005    71
# 2002    69
# 2008    67
# 2011    67
# 2009    66
# 1999    64
# 2010    63
# 2001    62
# 2004    61
# 2000    59
# 2003    58
# 2013    57
# 2007    54
# 2014    53
# 2012    49
# 1997    46
# 1996    46
# 1998    45
# 2015    41
# 1995    33
# 1994    31
# 2016    26
# 1992    22
# 1989    18
# 1990    18
# 1993    18
# 1985    14
# 1988    13
# 1991    12
# 1987    12
# 1986    11
# 1981    11
# 1982    10
# 1984    10
# 1983     9
# 1980     8
# 1977     6
# 1978     5
# 1979     4
# 1976     3
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.bar(release_month_counts.index, release_month_counts.values, color='turquoise', edgecolor='black')

plt.xticks(release_month_counts.index, release_month_counts.index, rotation=90)

plt.xlabel("Month of the Year", fontsize=14)
plt.ylabel("Total Movies Released", fontsize=14)
plt.title("Overall Distribution of Total Movies Released by Month of the Year", fontsize=16)

plt.show()

# %%
df['vote_average'].min()
# Out:
# 3.0

# %%
df['vote_average'].max()
# Out:
# 8.3

# %%
df['vote_average'].mean()
# Out:
# 6.368191126279864

# %%
df['vote_average'].median()
# Out:
# 6.4

# %%
df['vote_average'].max()
# Out:
# 8.3

# %%
df['vote_count'].max()
# Out:
# 13752

# %%
df[df['vote_average']==8.3]
# Out:
#       Unnamed: 0     id    budget  popularity    revenue             title  \
# 383          662  44259  63000000         146  100853753        Fight Club
# 901         1818  45415  22000000         104  321365567  Schindler's List
# 1284        3232  46829   8000000         121  213928762      Pulp Fiction
#
#       vote_average  vote_count  director_id  year month       day
# 383            8.3        9413         4829  1999   Oct    Friday
# 901            8.3        4329         4799  1993   Nov    Monday
# 1284           8.3        8428         4927  1994   Oct  Saturday

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x=df['vote_average'], color='gold')

plt.title('Box Plot of Vote Average', fontsize=16)
plt.xlabel('Vote Average')

plt.show()

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x=df['vote_count'], color='mediumturquoise')

plt.title('Box Plot of Vote Count', fontsize=16)
plt.xlabel('Vote Count')

plt.show()

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x=df['popularity'], color='yellowgreen')

plt.title('Box Plot of Popularity', fontsize=16)
plt.xlabel('Popularity')

plt.show()

# %%
df[df['vote_average']>8]
# Out:
#       Unnamed: 0     id     budget  popularity     revenue  \
# 45            65  43662  185000000         187  1004558444
# 58            95  43692  165000000         724   675120017
# 59            96  43693  160000000         167   825532764
# 199          329  43926   94000000         123  1118888979
# 383          662  44259   63000000         146   100853753
# 459          809  44406   55000000         138   677945399
# 785         1553  45150   33000000          79   327311859
# 901         1818  45415   22000000         104   321365567
# 917         1847  45444   25000000          63    46836394
# 1000        2091  45688   19000000          18   272742922
# 1284        3232  46829    8000000         121   213928762
# 1326        3454  47051    6000000          64    23341568
# 1341        3573  47170    9000000          60    39723096
#
#                                               title  vote_average  vote_count  \
# ...

# %%
df[df['vote_count']>10000]
# Out:
#      Unnamed: 0     id     budget  popularity     revenue             title  \
# 0             0  43597  237000000         150  2787965087            Avatar
# 45           65  43662  185000000         187  1004558444   The Dark Knight
# 58           95  43692  165000000         724   675120017      Interstellar
# 59           96  43693  160000000         167   825532764         Inception
# 178         287  43884  100000000          82   425368238  Django Unchained
#
#      vote_average  vote_count  director_id  year month        day
# 0             7.2       11800         4762  2009   Dec   Thursday
# 45            8.2       12002         4765  2008   Jul  Wednesday
# 58            8.1       10867         4765  2014   Nov  Wednesday
# 59            8.1       13752         4765  2010   Jul  Wednesday
# 178           7.8       10099         4927  2012   Dec    Tuesday

# %%
df['popularity'].value_counts()
# Out:
# popularity
# 14     45
# 16     42
# 5      41
# 7      39
# 6      38
#        ..
# 206     1
# 103     1
# 132     1
# 88      1
# 121     1
# Name: count, Length: 128, dtype: int64

# %%
df['popularity'].max()
# Out:
# 724

# %%
df[df['popularity']==724]
# Out:
#     Unnamed: 0     id     budget  popularity    revenue         title  \
# 58          95  43692  165000000         724  675120017  Interstellar
#
#     vote_average  vote_count  director_id  year month        day
# 58           8.1       10867         4765  2014   Nov  Wednesday

# %%
df[df['popularity']>200]
# Out:
#      Unnamed: 0     id     budget  popularity    revenue  \
# 58           95  43692  165000000         724  675120017
# 78          127  43724  150000000         434  378858340
# 119         199  43796  140000000         271  655011224
# 120         200  43797  125000000         206  752100229
#
#                                                  title  vote_average  \
# 58                                        Interstellar           8.1
# 78                                  Mad Max: Fury Road           7.2
# 119  Pirates of the Caribbean: The Curse of the Bla...           7.5
# 120              The Hunger Games: Mockingjay - Part 1           6.6
#
#      vote_count  director_id  year month        day
# 58        10867         4765  2014   Nov  Wednesday
# 78         9427         4845  2015   May  Wednesday
# 119        6985         4763  2003   Jul  Wednesday
# 120        5584         4831  2014   Nov    Tuesday

# %%
plt.figure(figsize=(10,6))
corr_matrix = df.drop(columns=['Unnamed: 0', 'title', 'month', 'day']).corr()
sns.heatmap(corr_matrix, annot=True, cmap='Blues', fmt='.2f')
plt.title('Correlation Heatmap')
plt.show()

# %%
sns.pairplot(df)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
sns.jointplot(x='budget', y='popularity', data=df, kind='hex', color='teal')
plt.suptitle('Joint Plot of Budget and Popularity', y=1.02)
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.jointplot(x='budget', y='revenue', data=df, kind='hex', color='teal')
plt.suptitle('Joint Plot of Budget and Revenue', y=1.02)
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
plt.figure(figsize=(8, 6))
sns.kdeplot(data=df, x='revenue', shade=True, color='purple')
plt.title('Density Plot of Revenue')
plt.xlabel('Revenue')
plt.ylabel('Density')
plt.show()
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_2808\3746191253.py:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data=df, x='revenue', shade=True, color='purple')
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
plt.figure(figsize=(8, 6))
sns.regplot(x='budget', y='revenue', data=df, scatter_kws={'alpha':0.5}, line_kws={'color':'red'})
plt.title('Budget vs. Revenue')
plt.xlabel('Revenue')
plt.ylabel('Budget')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df, x='revenue', y='popularity', palette='Set1', alpha=0.6)
plt.title('Popularity vs. Revenue')
plt.xlabel('Revenue')
plt.ylabel('Popularity')
plt.show()
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_2808\1183125493.py:2: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(data=df, x='revenue', y='popularity', palette='Set1', alpha=0.6)

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error, r2_score

features = df.drop(columns=['Unnamed: 0', 'title', 'month', 'day', 'budget'])
target = df['budget']

X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=29)

scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

rf_model = RandomForestRegressor(n_estimators=250, random_state=29)

rf_model.fit(X_train_scaled, y_train)
# Out:
# RandomForestRegressor(n_estimators=250, random_state=29)

# %%
y_pred_rf = rf_model.predict(X_test_scaled)

y_pred_rf
# Out:
# array([1.09000197e+07, 2.66380000e+07, 6.63920000e+07, 3.55791031e+06,
#        8.40140000e+07, 2.66920000e+07, 1.09196000e+07, 1.53252000e+08,
#        2.55844000e+07, 3.52453291e+06, 1.80496000e+07, 7.20760000e+07,
#        3.93320000e+07, 1.22688000e+07, 3.66283224e+06, 6.14304000e+07,
#        2.29624000e+08, 6.31960000e+06, 6.65000000e+06, 1.73220000e+07,
#        4.82800000e+07, 3.52280000e+07, 2.89773419e+06, 4.21200000e+06,
#        1.97620000e+07, 5.27852000e+07, 2.50240000e+07, 4.45840000e+07,
#        1.51916000e+08, 3.25659280e+07, 3.30208000e+05, 8.82880000e+06,
#        9.73000000e+07, 9.64966628e+06, 4.15392000e+07, 6.26568000e+07,
#        1.16000000e+04, 1.58576000e+07, 2.94760000e+07, 3.96880000e+07,
#        4.94200000e+07, 4.67294560e+07, 4.01240000e+07, 6.34360000e+07,
#        3.08400000e+06, 2.19560000e+07, 3.97640035e+07, 2.11444000e+07,
#        9.36520000e+07, 3.46059640e+07, 1.04604000e+07, 2.18800000e+08,
# ...

# %%
y_test
# Out:
# 1243    10000000
# 751     35000000
# 416     50000000
# 1356    15000000
# 244     85000000
#           ...
# 722     40000000
# 1419     1500000
# 1006    20000000
# 533     44000000
# 451     60000000
# Name: budget, Length: 293, dtype: int64

# %%
mae_rf = mean_absolute_error(y_test, y_pred_rf)
r2_rf = r2_score(y_test, y_pred_rf)

mae_rf, r2_rf
# Out:
# (6897351.39687372, 0.8961385131200946)

# %%
mean_budget = df['budget'].mean()
mean_budget
# Out:
# 48022946.87986348

# %%
error_percent = (mae_rf/mean_budget)*100
error_percent
# Out:
# 14.362615884711255

# %%
percentage_accuracy_of_budget = 100-error_percent
percentage_accuracy_of_budget
# Out:
# 85.63738411528874

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error, r2_score

features = df.drop(columns=['Unnamed: 0', 'title', 'month', 'day', 'vote_average'])
target = df['vote_average']

X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=29)

scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

rf_model = RandomForestRegressor(n_estimators=250, random_state=29)

rf_model.fit(X_train_scaled, y_train)
# Out:
# RandomForestRegressor(n_estimators=250, random_state=29)

# %%
y_pred_rf = rf_model.predict(X_test_scaled)
y_pred_rf
# Out:
# array([6.5808, 6.5152, 5.3768, 5.8024, 6.4932, 6.7076, 6.9764, 7.3448,
#        5.0276, 6.9632, 6.0588, 7.574 , 7.1788, 6.6488, 6.5288, 7.2364,
#        7.0536, 6.054 , 6.1564, 6.7084, 6.276 , 6.1028, 6.6332, 6.0344,
#        6.7568, 6.5204, 6.8424, 5.8564, 6.5776, 6.676 , 7.0684, 6.4276,
#        6.066 , 7.2508, 6.1212, 7.1976, 6.5844, 5.7176, 6.2584, 6.0396,
#        6.8116, 6.162 , 6.3128, 6.086 , 6.3312, 5.9296, 6.0884, 6.056 ,
#        5.7092, 6.3556, 6.2648, 6.9484, 6.0696, 5.9676, 5.7492, 6.6584,
#        7.6528, 6.258 , 6.1284, 6.5712, 6.4904, 6.6668, 5.9772, 6.4256,
#        6.8376, 6.254 , 6.2324, 6.0992, 6.6636, 6.0792, 6.5768, 5.978 ,
#        6.0996, 6.2916, 7.2496, 6.1624, 6.228 , 5.8712, 6.5456, 6.8456,
#        7.94  , 5.9864, 6.3008, 5.6804, 6.1196, 7.3488, 5.6752, 5.858 ,
#        6.9096, 6.2132, 5.818 , 7.2708, 5.9884, 6.41  , 4.522 , 6.6328,
#        5.864 , 5.4708, 6.6336, 6.4168, 6.5592, 7.2576, 6.0228, 5.9336,
# ...

# %%
y_test
# Out:
# 1243    5.9
# 751     6.8
# 416     4.5
# 1356    4.5
# 244     6.1
#        ...
# 722     6.7
# 1419    6.2
# 1006    6.7
# 533     6.0
# 451     4.9
# Name: vote_average, Length: 293, dtype: float64

# %%
mae_rf = mean_absolute_error(y_test, y_pred_rf)
r2_rf = r2_score(y_test, y_pred_rf)

mae_rf, r2_rf
# Out:
# (0.483714675767918, 0.461736385036254)

# %%
mean_popularity = df['popularity'].mean()
mean_popularity
# Out:
# 30.855972696245733

# %%
error_percent = (mae_rf/mean_popularity)*100
error_percent
# Out:
# 1.567653305017255

# %%
percentage_accuracy_of_popularity = 100-error_percent
percentage_accuracy_of_popularity
# Out:
# 98.43234669498274
